# %% [markdown]
# <a href="https://colab.research.google.com/github/HardikxLabeitazer/DataScience-Practice-/blob/master/MLBasics3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"


from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,BaggingClassifier,ExtraTreesClassifier,GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve ,KFold
from sklearn.metrics import roc_curve,accuracy_score,f1_score,auc,confusion_matrix,roc_auc_score
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('/content/drive/MyDrive/MachineLearning/BasicsPrac/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.head().style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_5c5ed_row0_col0, #T_5c5ed_row0_col2, #T_5c5ed_row0_col3, #T_5c5ed_row0_col5, #T_5c5ed_row0_col6, #T_5c5ed_row0_col9, #T_5c5ed_row0_col10, #T_5c5ed_row0_col11, #T_5c5ed_row1_col2, #T_5c5ed_row1_col7, #T_5c5ed_row1_col11, #T_5c5ed_row2_col11, #T_5c5ed_row3_col1, #T_5c5ed_row3_col3, #T_5c5ed_row3_col4, #T_5c5ed_row3_col8, #T_5c5ed_row4_col0, #T_5c5ed_row4_col2, #T_5c5ed_row4_col3, #T_5c5ed_row4_col5, #T_5c5ed_row4_col6, #T_5c5ed_row4_col9, #T_5c5ed_row4_col10, #T_5c5ed_row4_col11 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_5c5ed_row0_col1, #T_5c5ed_row4_col1 {
#   background-color: #b34cff;
#   color: #f1f1f1;
# }
# #T_5c5ed_row0_col4, #T_5c5ed_row4_col4 {
#   background-color: #0bf4ff;
#   color: #000000;
# }
# #T_5c5ed_row0_col7, #T_5c5ed_row4_col7 {
#   background-color: #d52aff;
#   color: #f1f1f1;
# }
# #T_5c5ed_row0_col8, #T_5c5ed_row1_col1, #T_5c5ed_row1_col3, #T_5c5ed_row1_col4, #T_5c5ed_row1_col5, #T_5c5ed_row1_col6, #T_5c5ed_row1_col9, #T_5c5ed_row1_col10, #T_5c5ed_row2_col10, #T_5c5ed_row3_col0, #T_5c5ed_row3_col2, #T_5c5ed_row3_col7, #T_5c5ed_row3_col10, #T_5c5ed_row3_col11, #T_5c5ed_row4_col8 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_5c5ed_row1_col0, #T_5c5ed_row2_col0 {
#   background-color: #1ae5ff;
#   color: #000000;
# }
# #T_5c5ed_row1_col8 {
#   background-color: #1de2ff;
#   color: #000000;
# }
# #T_5c5ed_row2_col1 {
#   background-color: #cc33ff;
#   color: #f1f1f1;
# }
# #T_5c5ed_row2_col2 {
#   background-color: #12edff;
#   color: #000000;
# }
# #T_5c5ed_row2_col3 {
#   background-color: #926dff;
#   color: #f1f1f1;
# }
# #T_5c5ed_row2_col4 {
#   background-color: #bd42ff;
#   color: #f1f1f1;
# }
# #T_5c5ed_row2_col5, #T_5c5ed_row2_col8 {
#   background-color: #49b6ff;
#   color: #000000;
# }
# #T_5c5ed_row2_col6 {
#   background-color: #9b64ff;
#   color: #f1f1f1;
# }
# #T_5c5ed_row2_col7, #T_5c5ed_row3_col9 {
#   background-color: #2ad5ff;
#   color: #000000;
# }
# #T_5c5ed_row2_col9 {
#   background-color: #bf40ff;
#   color: #f1f1f1;
# }
# #T_5c5ed_row3_col5 {
#   background-color: #6d92ff;
#   color: #f1f1f1;
# }
# #T_5c5ed_row3_col6 {
#   background-color: #c936ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5c5ed_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fixed acidity</th>
#       <th class="col_heading level0 col1" >volatile acidity</th>
#       <th class="col_heading level0 col2" >citric acid</th>
#       <th class="col_heading level0 col3" >residual sugar</th>
#       <th class="col_heading level0 col4" >chlorides</th>
#       <th class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th class="col_heading level0 col7" >density</th>
#       <th class="col_heading level0 col8" >pH</th>
#       <th class="col_heading level0 col9" >sulphates</th>
#       <th class="col_heading level0 col10" >alcohol</th>
#       <th class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c5ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c5ed_row0_col0" class="data row0 col0" >7.400000</td>
#       <td id="T_5c5ed_row0_col1" class="data row0 col1" >0.700000</td>
#       <td id="T_5c5ed_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_5c5ed_row0_col3" class="data row0 col3" >1.900000</td>
#       <td id="T_5c5ed_row0_col4" class="data row0 col4" >0.076000</td>
#       <td id="T_5c5ed_row0_col5" class="data row0 col5" >11.000000</td>
#       <td id="T_5c5ed_row0_col6" class="data row0 col6" >34.000000</td>
#       <td id="T_5c5ed_row0_col7" class="data row0 col7" >0.997800</td>
#       <td id="T_5c5ed_row0_col8" class="data row0 col8" >3.510000</td>
#       <td id="T_5c5ed_row0_col9" class="data row0 col9" >0.560000</td>
#       <td id="T_5c5ed_row0_col10" class="data row0 col10" >9.400000</td>
#       <td id="T_5c5ed_row0_col11" class="data row0 col11" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5c5ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5c5ed_row1_col0" class="data row1 col0" >7.800000</td>
#       <td id="T_5c5ed_row1_col1" class="data row1 col1" >0.880000</td>
#       <td id="T_5c5ed_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_5c5ed_row1_col3" class="data row1 col3" >2.600000</td>
#       <td id="T_5c5ed_row1_col4" class="data row1 col4" >0.098000</td>
#       <td id="T_5c5ed_row1_col5" class="data row1 col5" >25.000000</td>
#       <td id="T_5c5ed_row1_col6" class="data row1 col6" >67.000000</td>
#       <td id="T_5c5ed_row1_col7" class="data row1 col7" >0.996800</td>
#       <td id="T_5c5ed_row1_col8" class="data row1 col8" >3.200000</td>
#       <td id="T_5c5ed_row1_col9" class="data row1 col9" >0.680000</td>
#       <td id="T_5c5ed_row1_col10" class="data row1 col10" >9.800000</td>
#       <td id="T_5c5ed_row1_col11" class="data row1 col11" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5c5ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5c5ed_row2_col0" class="data row2 col0" >7.800000</td>
#       <td id="T_5c5ed_row2_col1" class="data row2 col1" >0.760000</td>
#       <td id="T_5c5ed_row2_col2" class="data row2 col2" >0.040000</td>
#       <td id="T_5c5ed_row2_col3" class="data row2 col3" >2.300000</td>
#       <td id="T_5c5ed_row2_col4" class="data row2 col4" >0.092000</td>
#       <td id="T_5c5ed_row2_col5" class="data row2 col5" >15.000000</td>
#       <td id="T_5c5ed_row2_col6" class="data row2 col6" >54.000000</td>
#       <td id="T_5c5ed_row2_col7" class="data row2 col7" >0.997000</td>
#       <td id="T_5c5ed_row2_col8" class="data row2 col8" >3.260000</td>
#       <td id="T_5c5ed_row2_col9" class="data row2 col9" >0.650000</td>
#       <td id="T_5c5ed_row2_col10" class="data row2 col10" >9.800000</td>
#       <td id="T_5c5ed_row2_col11" class="data row2 col11" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5c5ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5c5ed_row3_col0" class="data row3 col0" >11.200000</td>
#       <td id="T_5c5ed_row3_col1" class="data row3 col1" >0.280000</td>
#       <td id="T_5c5ed_row3_col2" class="data row3 col2" >0.560000</td>
#       <td id="T_5c5ed_row3_col3" class="data row3 col3" >1.900000</td>
#       <td id="T_5c5ed_row3_col4" class="data row3 col4" >0.075000</td>
#       <td id="T_5c5ed_row3_col5" class="data row3 col5" >17.000000</td>
#       <td id="T_5c5ed_row3_col6" class="data row3 col6" >60.000000</td>
#       <td id="T_5c5ed_row3_col7" class="data row3 col7" >0.998000</td>
#       <td id="T_5c5ed_row3_col8" class="data row3 col8" >3.160000</td>
#       <td id="T_5c5ed_row3_col9" class="data row3 col9" >0.580000</td>
#       <td id="T_5c5ed_row3_col10" class="data row3 col10" >9.800000</td>
#       <td id="T_5c5ed_row3_col11" class="data row3 col11" >6</td>
#     </tr>
#     <tr>
#       <th id="T_5c5ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5c5ed_row4_col0" class="data row4 col0" >7.400000</td>
#       <td id="T_5c5ed_row4_col1" class="data row4 col1" >0.700000</td>
#       <td id="T_5c5ed_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_5c5ed_row4_col3" class="data row4 col3" >1.900000</td>
#       <td id="T_5c5ed_row4_col4" class="data row4 col4" >0.076000</td>
#       <td id="T_5c5ed_row4_col5" class="data row4 col5" >11.000000</td>
#       <td id="T_5c5ed_row4_col6" class="data row4 col6" >34.000000</td>
#       <td id="T_5c5ed_row4_col7" class="data row4 col7" >0.997800</td>
#       <td id="T_5c5ed_row4_col8" class="data row4 col8" >3.510000</td>
#       <td id="T_5c5ed_row4_col9" class="data row4 col9" >0.560000</td>
#       <td id="T_5c5ed_row4_col10" class="data row4 col10" >9.400000</td>
#       <td id="T_5c5ed_row4_col11" class="data row4 col11" >5</td>
#     </tr>
#   </tbody>
# </table>

# %%
df1 = df.copy()

# %%
df.shape
# Out:
# (1599, 12)

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtypes != '0']
print('Number of numerical variables :',len(numerical_features))
print('-'*100)
print('Numerical variable column:',numerical_features)
# Out:
# Number of numerical variables : 12
# ----------------------------------------------------------------------------------------------------
# Numerical variable column: ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
df.ndim
# Out:
# 2

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1599, step=1)

# %%
df.size
# Out:
# 19188

# %%
def memory_use():
  print('/833[1m'+'Memory by all columns in bytes'+'/833[0m')

# %%
k = df.memory_usage()
print(k,'bytes'+'\n')
# Out:
# Index                     128
# fixed acidity           12792
# volatile acidity        12792
# citric acid             12792
# residual sugar          12792
# chlorides               12792
# free sulfur dioxide     12792
# total sulfur dioxide    12792
# density                 12792
# pH                      12792
# sulphates               12792
# alcohol                 12792
# quality                 12792
# dtype: int64 bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
from IPython.core.display import HTML
def multi_table(table_list):
    ''' Accepts a list of IpyTable objects and returns a table which contains each IpyTable in a cell
    '''
    return HTML(
        '<table><tr style="background-color:white;">' + 
        ''.join(['<td>' + table._repr_html_() + '</td>' for table in table_list]) +
        '</tr></table>')

# %%
df_nunique = {var:pd.DataFrame(df[var].value_counts())
              for var in {'quality'}}
multi_table([df_nunique['quality'].style.background_gradient(cmap='cool')])
# Out:
# <table><tr style="background-color:white;"><td><style type="text/css">
# #T_02701_row0_col0 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_02701_row1_col0 {
#   background-color: #ef10ff;
#   color: #f1f1f1;
# }
# #T_02701_row2_col0 {
#   background-color: #48b7ff;
#   color: #000000;
# }
# #T_02701_row3_col0 {
#   background-color: #10efff;
#   color: #000000;
# }
# #T_02701_row4_col0 {
#   background-color: #03fcff;
#   color: #000000;
# }
# #T_02701_row5_col0 {
#   background-color: #00ffff;
#   color: #000000;
# }
# </style>
# <table id="T_02701_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02701_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_02701_row0_col0" class="data row0 col0" >681</td>
#     </tr>
#     <tr>
#       <th id="T_02701_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_02701_row1_col0" class="data row1 col0" >638</td>
#     </tr>
#     <tr>
#       <th id="T_02701_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_02701_row2_col0" class="data row2 col0" >199</td>
#     </tr>
#     <tr>
#       <th id="T_02701_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_02701_row3_col0" class="data row3 col0" >53</td>
#     </tr>
#     <tr>
#       <th id="T_02701_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_02701_row4_col0" class="data row4 col0" >18</td>
#     </tr>
#     <tr>
#       <th id="T_02701_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_02701_row5_col0" class="data row5 col0" >10</td>
#     </tr>
#   </tbody>
# </table>
# </td></tr></table>

# %%
import missingno as mn
mn.matrix(df,color=(0.5,0.5,0.5),figsize = (10,4))

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df.drop_duplicates(inplace=True)

# %%
round(df.describe(exclude='object'),2).style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_93559_row0_col0, #T_93559_row0_col1, #T_93559_row0_col2, #T_93559_row0_col3, #T_93559_row0_col4, #T_93559_row0_col5, #T_93559_row0_col6, #T_93559_row0_col7, #T_93559_row0_col8, #T_93559_row0_col9, #T_93559_row0_col10, #T_93559_row0_col11 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_93559_row1_col0, #T_93559_row1_col10, #T_93559_row2_col5, #T_93559_row3_col10, #T_93559_row4_col0, #T_93559_row4_col5, #T_93559_row4_col10, #T_93559_row5_col0, #T_93559_row5_col10, #T_93559_row6_col0, #T_93559_row6_col10, #T_93559_row7_col11 {
#   background-color: #01feff;
#   color: #000000;
# }
# #T_93559_row1_col1, #T_93559_row1_col2, #T_93559_row1_col3, #T_93559_row1_col4, #T_93559_row1_col7, #T_93559_row1_col8, #T_93559_row1_col9, #T_93559_row1_col11, #T_93559_row2_col0, #T_93559_row2_col1, #T_93559_row2_col2, #T_93559_row2_col3, #T_93559_row2_col4, #T_93559_row2_col7, #T_93559_row2_col8, #T_93559_row2_col9, #T_93559_row2_col10, #T_93559_row2_col11, #T_93559_row3_col0, #T_93559_row3_col1, #T_93559_row3_col2, #T_93559_row3_col3, #T_93559_row3_col4, #T_93559_row3_col5, #T_93559_row3_col6, #T_93559_row3_col7, #T_93559_row3_col8, #T_93559_row3_col9, #T_93559_row3_col11, #T_93559_row4_col1, #T_93559_row4_col2, #T_93559_row4_col3, #T_93559_row4_col4, #T_93559_row4_col7, #T_93559_row4_col8, #T_93559_row4_col9, #T_93559_row4_col11, #T_93559_row5_col1, #T_93559_row5_col2, #T_93559_row5_col3, #T_93559_row5_col4, #T_93559_row5_col7, #T_93559_row5_col8, #T_93559_row5_col9, #T_93559_row5_col11, #T_93559_row6_col1, #T_93559_row6_col2, #T_93559_row6_col3, #T_93559_row6_col4, #T_93559_row6_col7, #T_93559_row6_col8, #T_93559_row6_col9, #T_93559_row6_col11, #T_93559_row7_col1, #T_93559_row7_col2, #T_93559_row7_col4, #T_93559_row7_col7, #T_93559_row7_col8, #T_93559_row7_col9 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_93559_row1_col5, #T_93559_row5_col5, #T_93559_row7_col0, #T_93559_row7_col3, #T_93559_row7_col10 {
#   background-color: #02fdff;
#   color: #000000;
# }
# #T_93559_row1_col6 {
#   background-color: #07f8ff;
#   color: #000000;
# }
# #T_93559_row2_col6 {
#   background-color: #05faff;
#   color: #000000;
# }
# #T_93559_row4_col6, #T_93559_row6_col5 {
#   background-color: #03fcff;
#   color: #000000;
# }
# #T_93559_row5_col6 {
#   background-color: #06f9ff;
#   color: #000000;
# }
# #T_93559_row6_col6 {
#   background-color: #0af5ff;
#   color: #000000;
# }
# #T_93559_row7_col5 {
#   background-color: #0df2ff;
#   color: #000000;
# }
# #T_93559_row7_col6 {
#   background-color: #35caff;
#   color: #000000;
# }
# </style>
# <table id="T_93559_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fixed acidity</th>
#       <th class="col_heading level0 col1" >volatile acidity</th>
#       <th class="col_heading level0 col2" >citric acid</th>
#       <th class="col_heading level0 col3" >residual sugar</th>
#       <th class="col_heading level0 col4" >chlorides</th>
#       <th class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th class="col_heading level0 col7" >density</th>
#       <th class="col_heading level0 col8" >pH</th>
#       <th class="col_heading level0 col9" >sulphates</th>
#       <th class="col_heading level0 col10" >alcohol</th>
#       <th class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93559_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_93559_row0_col0" class="data row0 col0" >1359.000000</td>
#       <td id="T_93559_row0_col1" class="data row0 col1" >1359.000000</td>
#       <td id="T_93559_row0_col2" class="data row0 col2" >1359.000000</td>
#       <td id="T_93559_row0_col3" class="data row0 col3" >1359.000000</td>
#       <td id="T_93559_row0_col4" class="data row0 col4" >1359.000000</td>
#       <td id="T_93559_row0_col5" class="data row0 col5" >1359.000000</td>
#       <td id="T_93559_row0_col6" class="data row0 col6" >1359.000000</td>
#       <td id="T_93559_row0_col7" class="data row0 col7" >1359.000000</td>
#       <td id="T_93559_row0_col8" class="data row0 col8" >1359.000000</td>
#       <td id="T_93559_row0_col9" class="data row0 col9" >1359.000000</td>
#       <td id="T_93559_row0_col10" class="data row0 col10" >1359.000000</td>
#       <td id="T_93559_row0_col11" class="data row0 col11" >1359.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93559_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_93559_row1_col0" class="data row1 col0" >8.310000</td>
#       <td id="T_93559_row1_col1" class="data row1 col1" >0.530000</td>
#       <td id="T_93559_row1_col2" class="data row1 col2" >0.270000</td>
#       <td id="T_93559_row1_col3" class="data row1 col3" >2.520000</td>
#       <td id="T_93559_row1_col4" class="data row1 col4" >0.090000</td>
#       <td id="T_93559_row1_col5" class="data row1 col5" >15.890000</td>
#       <td id="T_93559_row1_col6" class="data row1 col6" >46.830000</td>
#       <td id="T_93559_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_93559_row1_col8" class="data row1 col8" >3.310000</td>
#       <td id="T_93559_row1_col9" class="data row1 col9" >0.660000</td>
#       <td id="T_93559_row1_col10" class="data row1 col10" >10.430000</td>
#       <td id="T_93559_row1_col11" class="data row1 col11" >5.620000</td>
#     </tr>
#     <tr>
#       <th id="T_93559_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_93559_row2_col0" class="data row2 col0" >1.740000</td>
#       <td id="T_93559_row2_col1" class="data row2 col1" >0.180000</td>
#       <td id="T_93559_row2_col2" class="data row2 col2" >0.200000</td>
#       <td id="T_93559_row2_col3" class="data row2 col3" >1.350000</td>
#       <td id="T_93559_row2_col4" class="data row2 col4" >0.050000</td>
#       <td id="T_93559_row2_col5" class="data row2 col5" >10.450000</td>
#       <td id="T_93559_row2_col6" class="data row2 col6" >33.410000</td>
#       <td id="T_93559_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_93559_row2_col8" class="data row2 col8" >0.160000</td>
#       <td id="T_93559_row2_col9" class="data row2 col9" >0.170000</td>
#       <td id="T_93559_row2_col10" class="data row2 col10" >1.080000</td>
#       <td id="T_93559_row2_col11" class="data row2 col11" >0.820000</td>
#     </tr>
#     <tr>
#       <th id="T_93559_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_93559_row3_col0" class="data row3 col0" >4.600000</td>
#       <td id="T_93559_row3_col1" class="data row3 col1" >0.120000</td>
#       <td id="T_93559_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_93559_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_93559_row3_col4" class="data row3 col4" >0.010000</td>
#       <td id="T_93559_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_93559_row3_col6" class="data row3 col6" >6.000000</td>
#       <td id="T_93559_row3_col7" class="data row3 col7" >0.990000</td>
#       <td id="T_93559_row3_col8" class="data row3 col8" >2.740000</td>
#       <td id="T_93559_row3_col9" class="data row3 col9" >0.330000</td>
#       <td id="T_93559_row3_col10" class="data row3 col10" >8.400000</td>
#       <td id="T_93559_row3_col11" class="data row3 col11" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93559_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_93559_row4_col0" class="data row4 col0" >7.100000</td>
#       <td id="T_93559_row4_col1" class="data row4 col1" >0.390000</td>
#       <td id="T_93559_row4_col2" class="data row4 col2" >0.090000</td>
#       <td id="T_93559_row4_col3" class="data row4 col3" >1.900000</td>
#       <td id="T_93559_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_93559_row4_col5" class="data row4 col5" >7.000000</td>
#       <td id="T_93559_row4_col6" class="data row4 col6" >22.000000</td>
#       <td id="T_93559_row4_col7" class="data row4 col7" >1.000000</td>
#       <td id="T_93559_row4_col8" class="data row4 col8" >3.210000</td>
#       <td id="T_93559_row4_col9" class="data

# %%
plt.rcParams['font.family']=['serif']
background_color = '#ffff'
fig = plt.figure(figsize=(15,7),facecolor=background_color)
fig.suptitle('Distribution of the Fixed Acidity Before Treating Outlier',fontsize=30,fontweight ='bold')
ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"],y=df["fixed acidity"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["fixed acidity"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution of the Fixed Acidity Before Treating Outlier')
# (-0.5, 5.5, 4.034999999999999, 16.465)
# (2.6808483021557743, 17.819151697844227, 0.0, 0.3548613960030473)

# %%
df["Log_fixed acidity"]=np.log(df["fixed acidity"])
plt.rcParams['font.family']=['serif']
background_color = "#ffff"
fig = plt.figure(figsize=(15,7),facecolor=background_color)
fig.suptitle('Distribution of the Fixed Acidity After Treating Outlier',fontsize=30,fontweight='bold')
ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"],y=df["Log_fixed acidity"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x = df["Log_fixed acidity"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution of the Fixed Acidity After Treating Outlier')
# (-0.5, 5.5, 1.4640431632084923, 2.828332249512743)
# (1.3081175898196749, 2.9842578229015606, 0.0, 2.640702879889384)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Volatile Acidity Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["volatile acidity"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["volatile acidity"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Volatile Acidity Before Treating Oultier')
# (-0.5, 5.5, 0.047, 1.653)
# (-0.09569062975368034, 1.7956906297536803, 0.0, 2.357570534337297)

# %%
df["Log_volatile acidity"]=np.log(df["volatile acidity"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Volatitle After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_volatile acidity"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_volatile acidity"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Volatitle After Treating Outliers')
# (-0.5, 5.5, -2.2491479553620395, 0.5863092662008238)
# (-2.5265244461335117, 0.863685756972296, 0.0, 1.3038531632340873)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Citric Acidity', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["citric acid"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["citric acid"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Citric Acidity')
# (-0.5, 5.5, -0.05, 1.05)
# (-0.20243966466893276, 1.2024396646689328, 0.0, 3.244260485651214)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Residual Sugar Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["residual sugar"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["residual sugar"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Residual Sugar Before Treating Oultier')
# (-0.5, 5.5, 0.17000000000000004, 16.23)
# (-0.8842594798659709, 17.284259479865973, 0.0, 0.8969881157579599)

# %%
df["Log_residual sugar"]=np.log(df["residual sugar"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Residual Sugar After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_residual sugar"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_residual sugar"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Residual Sugar After Treating Outliers')
# (-0.5, 5.5, -0.24767054263697766, 2.8831500509043524)
# (-0.5205328213637102, 3.1560123296310847, 0.0, 3.2303628496248566)

# %%
df["Log_residual sugar"]=np.log(df["residual sugar"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Residual Sugar After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_residual sugar"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_residual sugar"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Residual Sugar After Treating Outliers')
# (-0.5, 5.5, -0.24767054263697766, 2.8831500509043524)
# (-0.5205328213637102, 3.1560123296310847, 0.0, 3.2303628496248566)

# %%
df["Log_chlorides"]=np.log(df["chlorides"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Chlorides After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_chlorides"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_chlorides"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Chlorides After Treating Outliers')
# (-0.5, 5.5, -4.619358144663317, -0.296148804341362)
# (-4.881337738367757, -0.03416921063692177, 0.0, 2.3393932002985567)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Free Sulfurdioxide Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["free sulfur dioxide"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["free sulfur dioxide"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Free Sulfurdioxide Before Treating Oultier')
# (-0.5, 5.5, -2.5500000000000003, 75.55)
# (-10.694658476278263, 83.69465847627826, 0.0, 0.07226782327519196)

# %%
df["Log_free sulfur dioxide"]=np.log(df["free sulfur dioxide"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Free Sulfurdioxide After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_free sulfur dioxide"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_free sulfur dioxide"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Free Sulfurdioxide After Treating Outliers')
# (-0.5, 5.5, -0.21383330595080277, 4.490499424966858)
# (-0.7469988499684044, 5.02366496898446, 0.0, 0.6120795898727687)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Total Sulfurdioxide Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["total sulfur dioxide"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["total sulfur dioxide"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Total Sulfurdioxide Before Treating Oultier')
# (-0.5, 5.5, -8.15, 303.15)
# (-34.19550720770688, 329.19550720770684, 0.0, 0.02001731682774437)

# %%
df["Log_total sulfur dioxide"]=np.log(df["total sulfur dioxide"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Total Sulfurdioxide After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_total sulfur dioxide"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_total sulfur dioxide"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Total Sulfurdioxide After Treating Outliers')
# (-0.5, 5.5, 1.598026108283836, 5.860160049056651)
# (1.0433136223029031, 6.414872535037585, 0.0, 0.5736873792116851)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Density', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["density"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["density"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Density')
# (-0.5, 5.5, 0.989389, 1.004371)
# (0.9879319981815609, 1.0058280018184391, 0.0, 266.164872460653)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The pH', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["pH"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["pH"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The pH')
# (-0.5, 5.5, 2.6765000000000003, 4.0735)
# (2.555634187634965, 4.194365812365034, 0.0, 3.421459734751669)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Sulphates Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["sulphates"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["sulphates"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Sulphates Before Treating Oultier')
# (-0.5, 5.5, 0.2465, 2.0835)
# (0.1134486380204123, 2.2165513619795876, 0.0, 4.418315686507767)

# %%
df["Log_sulphates"]=np.log(df["sulphates"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Sulphates After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_sulphates"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_sulphates"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Sulphates After Treating Outliers')
# (-0.5, 5.5, -1.198753114775689, 0.7832376708140232)
# (-1.3735377827538806, 0.9580223387922147, 0.0, 2.439048768832756)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Alcohol Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["alcohol"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["alcohol"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Alcohol Before Treating Oultier')
# (-0.5, 5.5, 8.075000000000001, 15.225)
# (7.231425236428579, 16.068574763571423, 0.0, 0.7080828663610123)

# %%
df["Log_alcohol"]=np.log(df["alcohol"])
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Alcohol After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_alcohol"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_alcohol"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Alcohol After Treating Outliers')
# (-0.5, 5.5, 2.099575230494161, 2.7300176883065204)
# (2.0213916915268415, 2.8082012272738397, 0.0, 7.190682039418455)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Before-Distribution Of The Quality', fontsize=30, fontweight='bold')
ax = sns.barplot(y = df['quality'].value_counts().values.tolist(), 
                      x = df['quality'].value_counts().index, palette="cool")
ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Text(0.5, 0.98, 'Before-Distribution Of The Quality')

# %%
bins = (2,6.5,8)
group_names = ['bad','good']
df['quality']=pd.cut(df['quality'],bins=bins,labels=group_names)

df['quality'].replace({'bad':0,'good':1},inplace=True)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('After-Distribution Of The Quality', fontsize=30, fontweight='bold')

ax = sns.barplot(y = df['quality'].value_counts().values.tolist(), 
                      x = df['quality'].value_counts().index, palette="cool")
ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Text(0.5, 0.98, 'After-Distribution Of The Quality')

# %%
df.drop(columns = ['fixed acidity', 'volatile acidity','residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide','sulphates', 'alcohol'],axis=True,inplace =True)

# %%
df = df[['Log_fixed acidity','Log_volatile acidity','citric acid', 'Log_residual sugar', 'Log_chlorides',
       'Log_free sulfur dioxide', 'Log_total sulfur dioxide','density',
       'pH','Log_sulphates','Log_alcohol','quality']]

# %%
df.head().style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_cddd3_row0_col0, #T_cddd3_row0_col2, #T_cddd3_row0_col5, #T_cddd3_row0_col6, #T_cddd3_row0_col9, #T_cddd3_row0_col10, #T_cddd3_row0_col11, #T_cddd3_row1_col2, #T_cddd3_row1_col7, #T_cddd3_row1_col11, #T_cddd3_row2_col11, #T_cddd3_row3_col1, #T_cddd3_row3_col4, #T_cddd3_row3_col8, #T_cddd3_row3_col11, #T_cddd3_row4_col0, #T_cddd3_row4_col2, #T_cddd3_row4_col3, #T_cddd3_row4_col4, #T_cddd3_row4_col9, #T_cddd3_row4_col10, #T_cddd3_row4_col11 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_cddd3_row0_col1 {
#   background-color: #cc33ff;
#   color: #f1f1f1;
# }
# #T_cddd3_row0_col3, #T_cddd3_row3_col3 {
#   background-color: #25daff;
#   color: #000000;
# }
# #T_cddd3_row0_col4 {
#   background-color: #0cf3ff;
#   color: #000000;
# }
# #T_cddd3_row0_col7, #T_cddd3_row4_col7 {
#   background-color: #d52aff;
#   color: #f1f1f1;
# }
# #T_cddd3_row0_col8, #T_cddd3_row1_col1, #T_cddd3_row1_col3, #T_cddd3_row1_col4, #T_cddd3_row1_col5, #T_cddd3_row1_col6, #T_cddd3_row1_col9, #T_cddd3_row1_col10, #T_cddd3_row2_col10, #T_cddd3_row3_col0, #T_cddd3_row3_col2, #T_cddd3_row3_col7, #T_cddd3_row3_col10, #T_cddd3_row4_col8 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_cddd3_row1_col0, #T_cddd3_row2_col0 {
#   background-color: #20dfff;
#   color: #000000;
# }
# #T_cddd3_row1_col8 {
#   background-color: #1de2ff;
#   color: #000000;
# }
# #T_cddd3_row2_col1 {
#   background-color: #df20ff;
#   color: #f1f1f1;
# }
# #T_cddd3_row2_col2 {
#   background-color: #12edff;
#   color: #000000;
# }
# #T_cddd3_row2_col3 {
#   background-color: #aa55ff;
#   color: #f1f1f1;
# }
# #T_cddd3_row2_col4 {
#   background-color: #c33cff;
#   color: #f1f1f1;
# }
# #T_cddd3_row2_col5 {
#   background-color: #609fff;
#   color: #f1f1f1;
# }
# #T_cddd3_row2_col6 {
#   background-color: #ae51ff;
#   color: #f1f1f1;
# }
# #T_cddd3_row2_col7 {
#   background-color: #2ad5ff;
#   color: #000000;
# }
# #T_cddd3_row2_col8 {
#   background-color: #49b6ff;
#   color: #000000;
# }
# #T_cddd3_row2_col9 {
#   background-color: #c43bff;
#   color: #f1f1f1;
# }
# #T_cddd3_row3_col5 {
#   background-color: #8778ff;
#   color: #f1f1f1;
# }
# #T_cddd3_row3_col6 {
#   background-color: #d629ff;
#   color: #f1f1f1;
# }
# #T_cddd3_row3_col9 {
#   background-color: #2ed1ff;
#   color: #000000;
# }
# #T_cddd3_row4_col1 {
#   background-color: #bf40ff;
#   color: #f1f1f1;
# }
# #T_cddd3_row4_col5 {
#   background-color: #34cbff;
#   color: #000000;
# }
# #T_cddd3_row4_col6 {
#   background-color: #3dc2ff;
#   color: #000000;
# }
# </style>
# <table id="T_cddd3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Log_fixed acidity</th>
#       <th class="col_heading level0 col1" >Log_volatile acidity</th>
#       <th class="col_heading level0 col2" >citric acid</th>
#       <th class="col_heading level0 col3" >Log_residual sugar</th>
#       <th class="col_heading level0 col4" >Log_chlorides</th>
#       <th class="col_heading level0 col5" >Log_free sulfur dioxide</th>
#       <th class="col_heading level0 col6" >Log_total sulfur dioxide</th>
#       <th class="col_heading level0 col7" >density</th>
#       <th class="col_heading level0 col8" >pH</th>
#       <th class="col_heading level0 col9" >Log_sulphates</th>
#       <th class="col_heading level0 col10" >Log_alcohol</th>
#       <th class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cddd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cddd3_row0_col0" class="data row0 col0" >2.001480</td>
#       <td id="T_cddd3_row0_col1" class="data row0 col1" >-0.356675</td>
#       <td id="T_cddd3_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_cddd3_row0_col3" class="data row0 col3" >0.641854</td>
#       <td id="T_cddd3_row0_col4" class="data row0 col4" >-2.577022</td>
#       <td id="T_cddd3_row0_col5" class="data row0 col5" >2.397895</td>
#       <td id="T_cddd3_row0_col6" class="data row0 col6" >3.526361</td>
#       <td id="T_cddd3_row0_col7" class="data row0 col7" >0.997800</td>
#       <td id="T_cddd3_row0_col8" class="data row0 col8" >3.510000</td>
#       <td id="T_cddd3_row0_col9" class="data row0 col9" >-0.579818</td>
#       <td id="T_cddd3_row0_col10" class="data row0 col10" >2.240710</td>
#       <td id="T_cddd3_row0_col11" class="data row0 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cddd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cddd3_row1_col0" class="data row1 col0" >2.054124</td>
#       <td id="T_cddd3_row1_col1" class="data row1 col1" >-0.127833</td>
#       <td id="T_cddd3_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_cddd3_row1_col3" class="data row1 col3" >0.955511</td>
#       <td id="T_cddd3_row1_col4" class="data row1 col4" >-2.322788</td>
#       <td id="T_cddd3_row1_col5" class="data row1 col5" >3.218876</td>
#       <td id="T_cddd3_row1_col6" class="data row1 col6" >4.204693</td>
#       <td id="T_cddd3_row1_col7" class="data row1 col7" >0.996800</td>
#       <td id="T_cddd3_row1_col8" class="data row1 col8" >3.200000</td>
#       <td id="T_cddd3_row1_col9" class="data row1 col9" >-0.385662</td>
#       <td id="T_cddd3_row1_col10" class="data row1 col10" >2.282382</td>
#       <td id="T_cddd3_row1_col11" class="data row1 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cddd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cddd3_row2_col0" class="data row2 col0" >2.054124</td>
#       <td id="T_cddd3_row2_col1" class="data row2 col1" >-0.274437</td>
#       <td id="T_cddd3_row2_col2" class="data row2 col2" >0.040000</td>
#       <td id="T_cddd3_row2_col3" class="data row2 col3" >0.832909</td>
#       <td id="T_cddd3_row2_col4" class="data row2 col4" >-2.385967</td>
#       <td id="T_cddd3_row2_col5" class="data row2 col5" >2.708050</td>
#       <td id="T_cddd3_row2_col6" class="data row2 col6" >3.988984</td>
#       <td id="T_cddd3_row2_col7" class="data row2 col7" >0.997000</td>
#       <td id="T_cddd3_row2_col8" class="data row2 col8" >3.260000</td>
#       <td id="T_cddd3_row2_col9" class="data row2 col9" >-0.430783</td>
#       <td id="T_cddd3_row2_col10" class="data row2 col10" >2.282382</td>
#       <td id="T_cddd3_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cddd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cddd3_row3_col0" class="data row3 col0" >2.415914</td>
#       <td id="T_cddd3_row3_col1" class="data row3 col1" >-1.272966</td>
#       <td id="T_cddd3_row3_col2" class="data row3 col2" >0.560000</td>
#       <td id="T_cddd3_row3_col3" class="data row3 col3" >0.641854</td>
#       <td id="T_cddd3_row3_col4" class="data row3 col4" >-2.590267</td>
#       <td id="T_cddd3_row3_col5" class="data row3 col5" >2.833213</td>
#       <td id="T_cddd3_row3_col6" class="data row3 col6" >4.094345</td>
#       <td id="T_cddd3_row3_col7" class="data row3 col7" >0.998000</td>
#       <td id="T_cddd3_row3_col8" class="data row3 col8" >3.160000</td>
#       <td id="T_cddd3_row3_col9" class="data row3 col9" >-0.544727</td>
#       <td id="T_cddd3_row3_col10" class="data row3 col10" >2.282382</td>
#       <td id="T_cddd3_row3_col11" class="data row3 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cddd3_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_cddd3_row4_col0" class="data row4 col0" >2.001480</td>
#       <td id="T_cddd3_row4_col1" class="data row4 col1" >-0.415515</td>
#       <td id="T_cddd3_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_cddd3_row4_col3" class="data row4 col3" >0.587787</td>
#       <td id="T_cddd3_row4_col4" class="data row4 col4" >-2.590267</td>
#       <td id="T_cddd3_row4_col5" class="data row4 col5" >2.564949</td>
#       <td id="T_cddd3_row4_col6" class="data row4 col6" >3.688879</td>
#       <td id="T_cddd3_row4_col7" class="data row4 col7" >0.997800</td>
#       <td id="T_cddd3_row4_col8" class="data row4 col8" >3.510000</td>
#       <td id="T_cddd3_row4_col9" class="data row4 col9" >-0.579818</td>
#       <td id="T_cddd3_row4_col10" class="data row4 col10" >2.240710</td>
#       <td id="T_cddd3_row4_col11" class="data row4 col11" >0</t

# %%
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
sns.pairplot(df,hue='quality',palette="cool")

# %%
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
sns.heatmap(df.corr(), annot=True,cmap = "cool",linewidths=2,linecolor = "white",cbar=True,annot_kws={"size":20})

# %%
background_color = "#ffffff"
fig = plt.figure(figsize=(20,7), facecolor=background_color)
gs = fig.add_gridspec(1, 1)
ax0 = fig.add_subplot(gs[0, 0])
ax0.set_facecolor(background_color)
ax0.text(-1.1, 1.25, 'Correlation of Numerical Features with Target', fontsize=30, fontweight='bold')

chart_df = pd.DataFrame(df.corrwith(df['quality']))
chart_df.columns = ['corr']
sns.barplot(x=chart_df.index, y=chart_df['corr'], ax=ax0, palette='cool',edgecolor="black",linewidth=3)
ax0.grid(which='major', axis='x', zorder=0, color='#EEEEEE', linewidth=0.4)
ax0.grid(which='major', axis='y', zorder=0, color='#EEEEEE', linewidth=0.4)
ax0.set_ylabel('')

for s in ["top","right", 'left']:
    ax0.spines[s].set_visible(False)

plt.show()
# Out:
# Text(-1.1, 1.25, 'Correlation of Numerical Features with Target')
# Text(0, 0.5, '')

# %%
x = df.drop('quality',axis=1)

Y = df['quality']
x_train,x_test,Y_train,Y_test = train_test_split(x,Y,test_size=0.25,random_state=44)

# %%
pca = PCA(n_components=None)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)
explained_variance = pca.explained_variance_ratio_
print(explained_variance)
# Out:
# [5.85683601e-01 1.08632262e-01 9.84931406e-02 7.64697288e-02
#  6.04286021e-02 2.88574041e-02 2.50035979e-02 7.60575720e-03
#  4.80782361e-03 4.01777389e-03 3.08123008e-07]

# %%
len(explained_variance)
# Out:
# 11

# %%
print("Sorted List returned :")
print(sorted(explained_variance,reverse = True))
# Out:
# Sorted List returned :
# [0.5856836011918456, 0.10863226242281968, 0.09849314064863694, 0.0764697287737392, 0.06042860209659454, 0.028857404125893812, 0.02500359792368141, 0.007605757196793903, 0.0048078236098962925, 0.004017773887090501, 3.081230082279486e-07]

# %%
background_color = "#ffffff"
fig = plt.figure(figsize=(20,7), facecolor=background_color)
plt.bar(range(11), explained_variance, alpha=0.5, align='center',label='Individual Explained Variance')
plt.ylabel('Explained Variance Ratio',fontsize = 18)
plt.xlabel('Principal Components',fontsize = 18)
plt.title('Explained Variance Ration vs Principal Components',fontsize = 25)
plt.legend(loc='best',fontsize = 18)
#plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# <BarContainer object of 11 artists>
# Text(0, 0.5, 'Explained Variance Ratio')
# Text(0.5, 0, 'Principal Components')
# Text(0.5, 1.0, 'Explained Variance Ration vs Principal Components')

# %%
kfold = StratifiedKFold(n_splits=8,shuffle=True, random_state=42)


rs = 15
clrs = []

clrs.append(AdaBoostClassifier(random_state=rs))
clrs.append(GradientBoostingClassifier(random_state=rs))
clrs.append(RandomForestClassifier(random_state=rs))
clrs.append(DecisionTreeClassifier(random_state = rs))

cv_results = []
for clr in clrs :
    cv_results.append(cross_val_score(clr, x_train, Y_train , scoring = 'accuracy', cv = kfold, n_jobs=-1))

cv_means = []
cv_std = []
for cv_result in cv_results:
    cv_means.append(cv_result.mean())
    cv_std.append(cv_result.std())
    
cv_df = pd.DataFrame({"CrossVal_Score_Means":cv_means,"CrossValerrors": cv_std,"Algo":["RandomForestClassifier","AdaBoostClassifier","Gradient Boosting",'DecisionTreeClassifier']})
g = sns.barplot("CrossVal_Score_Means","Algo",data = cv_df,orient = "h",**{'xerr':cv_std},palette='cool',edgecolor="black",linewidth=3)
g.set_xlabel("Mean Accuracy",fontsize = 18)
g = g.set_title("Cross validation scores",fontsize = 24)
plt.figure(figsize = (15,7))
print(cv_df)
# Out:
# Text(0.5, 0, 'Mean Accuracy')
#    CrossVal_Score_Means  CrossValerrors                    Algo
# 0              0.850763        0.033196  RandomForestClassifier
# 1              0.871378        0.026050      AdaBoostClassifier
# 2              0.878291        0.015396       Gradient Boosting
# 3              0.801727        0.035518  DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, Y_train)
Y_pred = dtc.predict(x_test)
confusion_matrix(Y_test, Y_pred)
# Out:
# DecisionTreeClassifier()
# array([[257,  36],
#        [ 26,  21]])

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89       293
#            1       0.37      0.45      0.40        47
#
#     accuracy                           0.82       340
#    macro avg       0.64      0.66      0.65       340
# weighted avg       0.83      0.82      0.82       340

# %%
print(accuracy_score(Y_test, Y_pred))
# Out:
# 0.8176470588235294
